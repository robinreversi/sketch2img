# %%
from EitzDataset import EitzDataset

# %%
ds = EitzDataset('val')
# Out:
# [Pandas(filepath='pretzel/13082.png', label=137), Pandas(filepath='pretzel/13083.png', label=137), Pandas(filepath='pretzel/13074.png', label=137), Pandas(filepath='pretzel/13045.png', label=137), Pandas(filepath='pretzel/13088.png', label=137), Pandas(filepath='pretzel/13044.png', label=137), Pandas(filepath='pretzel/13053.png', label=137), Pandas(filepath='pretzel/13108.png', label=137), Pandas(filepath='pretzel/13099.png', label=137), Pandas(filepath='pretzel/13116.png', label=137), Pandas(filepath='baseball bat/988.png', label=70), Pandas(filepath='baseball bat/1006.png', label=70), Pandas(filepath='baseball bat/963.png', label=70), Pandas(filepath='baseball bat/990.png', label=70), Pandas(filepath='baseball bat/1026.png', label=70), Pandas(filepath='baseball bat/1034.png', label=70), Pandas(filepath='baseball bat/978.png', label=70), Pandas(filepath='baseball bat/966.png', label=70), Pandas(filepath='baseball bat/985.png', label=70), Pandas(filepath='baseball bat/977.png', label
# ...

# %%
ds[0]
# Out:
# (array([[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255]], dtype=uint8), 137)
